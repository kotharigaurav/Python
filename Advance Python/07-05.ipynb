# %% [markdown]
# ## NUMPY

# %% [markdown]
# #### API ---> Application Programming Interface

# %%
import requests

# %%
print(dir(requests))
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_internal_utils', 'adapters', 'api', 'auth', 'certs', 'chardet', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'pyopenssl', 'request', 'session', 'sessions', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings']

# %%
import json
token = "EAAImpvNksncBAP74rwt3iOFCwLkZBBoBMMhhDzmnJJvY35DZCIoPOEFPDjmyspiBVJCqHIP823TMFXoIEe8gyPoTGLvSN1rUl5lRSQn2SVZCZAxdrjhJZCJZCyuXwPVC5gSZAXZA5GgnZCiW7Wpn8U5DAlOiCZB2aFszQJE9sYZBjQSfNdixrKncmIYGzkI7XkimjnmrSOMSY8kTgZDZD"
query  = input("Enter your query")
url = f"https://graph.facebook.com/v3.3/me?fields={query}&access_token={token}"
page = requests.get(url)
if page.status_code == 200:
    data = page.json()
    print(json.dumps(data,indent=5))
else:
    print("something went wrong")
# Out:
# Enter your queryname,hometown,friends
# {
#      "name": "Gaurav Kothari",
#      "hometown": {
#           "id": "128571363845632",
#           "name": "Bhawani Mandi, India"
#      },
#      "friends": {
#           "data": [],
#           "summary": {
#                "total_count": 300
#           }
#      },
#      "id": "414811765789737"
# }

# %%
url = "https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.content[:10]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF'

# %%
f = open("myimg.jpeg","wb")
f.write(page.content)
f.close()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img = plt.imread("myimg.jpeg")
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
url = [
    "http://www.hdnicewallpapers.com/Walls/Big/Cricket/Virat_Kohli_in_T20_Worldcup_Cricket_HD_Wallpaper.jpg",
    "https://i.pinimg.com/originals/cc/0c/b3/cc0cb389b89c825c85c273d12a8a6fcd.jpg",
    "https://rukminim1.flixcart.com/image/704/704/poster/g/g/c/medium-poster601-ms-dhoni-cricket-on-fine-art-paper-hd-quality-original-imaeg56zgfh3ddyu.jpeg?q=70",
    "http://www.sarkarinaukrisearch.in/wp-content/uploads/2019/01/indian-csdricket-team-image.jpg",
    "https://wallpaperbro.com/img/630407.jpg"
]

# %%
import bs4

# %%
page.status_code
# Out:
# 200

# %%
page.headers
# Out:
# {'ETag': '"697069e537c94abd91e04d1e45c70e6444224a93"', 'x-app-usage': '{"call_count":5,"total_cputime":0,"total_time":2}', 'Content-Type': 'application/json; charset=UTF-8', 'facebook-api-version': 'v3.3', 'Strict-Transport-Security': 'max-age=15552000; preload', 'Pragma': 'no-cache', 'x-fb-rev': '1000912706', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'x-fb-trace-id': 'EpAo6/kEGOQ', 'x-fb-request-id': 'AS0y9d8ZzqujzHD-Z5Xglx4', 'Expires': 'Sat, 01 Jan 2000 00:00:00 GMT', 'X-FB-Debug': 'Xl9ihAWZuLbztkTEd8nGVsvK6qkfQGNzrMJXK4rTX/mUwSu8AnkJSPLLeyQ28yEZ9X00DcJXSO0fu7l/TNDCGw==', 'Date': 'Fri, 05 Jul 2019 08:41:58 GMT', 'X-FB-TRIP-ID': '1886706526', 'Connection': 'keep-alive', 'Content-Length': '166'}

# %%
import os
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
def download_image(url):
    if "?" in url:
         url = url.split("?")[0]
    fname = url.split("/")[-1]
    try:
        page = requests.get(url)
        if page.status_code == 200 and "image/jpeg" in page.headers['C']

# %%
import os
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
def download_image(url):
    if "?" in url : 
        url = url.split("?")[0]
    fname = url.split("/")[-1]
    try : 
        page = requests.get(url)
        if page.status_code == 200 and "image/jpeg" in page.headers['Content-Type']:
                fp = open(fname,"xb")
                fp.write(page.content)
                fp.close()
                print(f"{fname} is successfully Download")
        else : 
            error = open("error.txt","a")
            print(f"{url} The Requested url does not return valid image",
                 file=error)
            error.close()
    except FileExistsError as e : 
        error = open("error.txt","a")
        print("File Already exists ",file=error)
        print("skipping this image",file=error)
        error.close()
    except Exception as e : 
        if os.path.exists(fname) : 
            if not fp.closed : 
                fp.close()
            os.unlink(fname)
        error = open("error.txt","a")
        print("Something Went Wrong ",e,file=error)
        error.close()
    finally :
        if "fp" in locals() and not fp.closed : 
            fp.close()
        
        
def show_img(fname):
    if os.path.exists(fname):
        img = plt.imread(fname)
        plt.imshow(img)
        plt.xticks([])
        plt.yticks([])
        plt.show()
    else : 
        with open("error.txt","a") as error : 
            print(f"{fname} file does not exists",file=error)
            error.close()

download_image("https://html5box.com/html5gallery/images/Swan_1024.jpg")
# Out:
# Swan_1024.jpg is successfully Download

# %%
for link in url :
    download_image(link)
    show_img(link.split("/")[-1])
# Out:
# Virat_Kohli_in_T20_Worldcup_Cricket_HD_Wallpaper.jpg is successfully Download
# cc0cb389b89c825c85c273d12a8a6fcd.jpg is successfully Download
# medium-poster601-ms-dhoni-cricket-on-fine-art-paper-hd-quality-original-imaeg56zgfh3ddyu.jpeg is successfully Download
# indian-csdricket-team-image.jpg is successfully Download
# 630407.jpg is successfully Download

# %% [markdown]
# ## Practice

# %% [markdown]
# ## Data Collection
# #### well known data sources
# ** kaggle **
#
# ** uci machine learning **
#
# ** government sites **
# ### most used in live environments
# ** using apis **
#
# ** web scraping **
# ### what is an api?

# %%
import requests

# %%
import json
token = "EAAImpvNksncBALL3nPyLQV4WrqWFZAAdNCnb3zFc4YwNFhZCOnk2SyNfqYITnnaZBZBcAtZChgOtcQPaki2FRr4pQB5urZCAK94RkachFG1lfpU7zkdKZBzeUPVZCCJw3PcwDEQ8i2fhBnU0RGwKdyMIwRumYnv9UGl593Xj8rzd3fDnMZABCHM4JtVZBxfg986eqdCWmMz5NnBmH01tVwZCeJlD8K1rpQWNKZC0mveDjkjYTAZDZD"
query = input("Enter Your query")
url = f"https://graph.facebook.com/v3.3/me?fields={query}&access_token={token}"
page = requests.get(url)
if page.status_code == 200:
    data = page.json()
    print(json.dumps(data,indent=5))
else:
    print("something went wrong")
# Out:
# Enter Your queryname,hometown,birthday,friends,posts
# {
#      "name": "Gaurav Kothari",
#      "hometown": {
#           "id": "128571363845632",
#           "name": "Bhawani Mandi, India"
#      },
#      "birthday": "06/03/1999",
#      "friends": {
#           "data": [],
#           "summary": {
#                "total_count": 300
#           }
#      },
#      "posts": {
#           "data": [
#                {
#                     "message": "Sister, you are my everything and even more. I feel that I\u2019m definitely one of the luckiest! Happy Birthday.\ud83c\udf89",
#                     "created_time": "2018-11-13T19:16:42+0000",
#                     "id": "414811765789737_312345119369736"
#                },
#                {
#                     "message": "Happy wala bday bhai... Shubham Suwalka\nParty hard",
#                     "created_time": "2018-09-03T20:35:47+0000",
#                     "id": "414811765789737_288827818388133"
#                },
# ...

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'{"name":"Gaurav Kothari","id":"414811765789737"}'

# %%
page.text
# Out:
# '{"name":"Gaurav Kothari","id":"414811765789737"}'

# %%
import requests
url ="https://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2018/11/28/Pictures/_3ca6a7a8-f2cc-11e8-84c6-a70c31b0a588.jpg"
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.content[:10]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF'

# %%
fp = open("crik1.jpg","wb")
fp.write(page.content)
fp.close()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread("crik1.jpg")
print(img.shape)
plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()
# Out:
# (540, 960, 3)

# %%
import requests
url = "https://www.sportswallah.com/wp-content/uploads/2019/04/Indian-team-SW-prediction-English.jpg"
page = requests.get(url)
fp = open("crik2.jpg","wb")
fp.write(page.content)
fp.close()
import matplotlib.pyplot as plt
# %matplotlib inline
img = plt.imread("crik2.jpg")
print(img.shape)
plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()
# Out:
# (800, 1000, 3)

# %%
url = [
    "http://www.baltana.com/files/wallpapers-3/Virat-Kohli-HD-Wallpaper-13185.jpg",
    "https://i.pinimg.com/originals/e1/86/50/e18650b23b09d4c44f3b120d1e22eab7.jpg",
    "http://wallpapersdsc.net/wp-content/uploads/2015/12/10146.jpg"
]

# %%
import os
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
def down_img(url):
    if "?" in url:
        url = url.split("?")[0]
    fname = url.split("/")[-1]
    try :
        page = requests.get(url)
        if page.status_code == 200 and "image/jpeg" in page.headers['Content-Type']:
                fp = open("crik3.jpg","xb")
                fp.write(page.content)
                fp.close()
                print(f"{fname} is successfully Download")
        else:
            error = open("error.txt","a")
            print(f"{url} The Requested url does not return valid image",file=error)
            error.close()
    except FileExistsError as e :
        error = open("error.txt","a")
        print("File Already exists ",file=error)
        print("skipping this image",file=error)
        error.close()
    except Exception as e :
        if os.path.exists(fname):
            if not fp.closed:
                fp.close()
            os.unlink(fname)
        error = open("error.txt","a")
        print("Something Went Wrong ",e,file=error)
        error.close()
    finally :
        if "fp" in locals() and not fp.closed :
            fp.close()


def show_img(fname):
    if os.path.exists(fname):
        img = plt.imread(fname)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(img)
        plt.show()
    else:
        with open("error.txt","a") as error : 
            print(f"{fname} file does not exists",file=error)
            error.close()
        print("something went wrong")

# %%
for link in url :
    down_img(link)
    show_img(link.split("/")[-1])

# %%
a = [1,2,3,4,5]
if True and 5 in a :
        print("hello")
# Out:
# hello

# %%
page.headers['Content-Type']
# Out:
# 'image/jpeg'

# %%
page.status_code
# Out:
# 200

# %%
page.history
# Out:
# []

# %%
page.url
# Out:
# 'http://wallpapersdsc.net/wp-content/uploads/2015/12/10146.jpg'

# %%
page = requests.get("https://grras.com")

# %%
page.status_code
# Out:
# 200

# %%
page.content[:50]
# Out:
# b'<!doctype html>\n<html class="no-js" lang="">\n    <'

# %%
page.headers["Content-Type"]
# Out:
# 'text/html; charset=UTF-8'

# %%
down_img("https://grras.com")

# %%
fp = open("grras.html","wb")
fp.write(page.content)
page.close()

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(page.text,'html')
# Out:
# C:\Users\Education\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Education\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Grras Solutions – AWS-Cloud, CCNA &amp; RedHat Linux Certification &amp; Training</title>
# <meta content="CCNA training in Jaipur, CCNA training in Ahmedabad, RedHat Certification in Jaipur, RedHat Certification in Indore, RedHat Certification in Ahmedabad, AWS Cloud Certification in Jaipur, AWS Cloud Certification in Indore, AWS Cloud Certification in Ahmedabad" name="keywords"/>
# <meta content="Grras Solutions is one of the best CCNA, Red Hat Linux ( RHCSA &amp; RHCE ) and AWS cloud Certification and training provider in Jaipur, Ahmedabad and Indore." name="description"/>
# <link href="https://grras.com/" rel="canonical"/>
# <meta content="Linux Training Institute, RedHat Training Center" name="classification"/>
# <meta content="Linux Training Institute, RedHat Training Center" name="copyright"/>
# ...

# %%
links = soup.find_all("img")

# %%
len(links)
# Out:
# 61

# %%
links[0]
# Out:
# <img alt="Grras Solutions Pvt. Ltd." class="img-responsive" src="https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60"/>

# %%
e = links[0]

# %%
e.get('src')
# Out:
# 'https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60'

# %%
urls = []

# %%
for link in links:
    urls.append(link.get('src'))

# %%
urls[::5]
# Out:
# ['https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/files/i28m4farnlyzxx6wxpxs/redhat optimized.jpg?s=157x130',
#  'https://grras.com/files/18glfshcmdaz9c1cdczp/Ansible optimize.jpg?s=157x130',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/files/gws5ixyl7kiaim39xl26/Rohit optimize.jpg?s=100x100',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=60x51']

# %%
for url in urls : 
    down_img(url)
    if "?" in url : 
        url = url.split("?")[0]
    show_img(url.split('/')[-1])
# Out:
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# something went wrong
# ...

# %%
down_img('https://grras.com/files/v0n5yzrqfuprbxidndbx/Home page IT.jpg?s=1200x500')
